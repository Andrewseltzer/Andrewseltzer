# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrewseltzer/StatisticsHomework/blob/main/Andrew_Seltzer_Loading_images%20Lab%20%234.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from skimage.io import imread

# %%
url = 'https://raw.githubusercontent.com/williamedwardhahn/
Data_Sci/main/dataset/train/cat/download.jpg'

# %%
url = 'https://github.com/Andrewseltzer/StatisticsHomework/blob/main/datset/ski/images-31.jpeg?raw=true'

# %%
im = imread(url)

# %%
plt.figure(figsize=(20,10))
plt.imshow(im);
plt.axis('off');
