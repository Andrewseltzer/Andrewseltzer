# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrewseltzer/StatisticsHomework/blob/main/Copy_of_Andrew_Seltzer_Loading_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize

# %%
url = 'https://raw.githubusercontent.com/williamedwardhahn/
Data_Sci/main/dataset/train/cat/download.jpg'

# %%
url = 'https://github.com/Andrewseltzer/StatisticsHomework/blob/main/datset/ski/images-31.jpeg?raw=true'

# %%
im = imread(url)

# %%
im.shape
# Out:
# (127, 398, 3)

# %%
im
# Out:
# array([[[138, 180, 222],
#         [138, 180, 222],
#         [139, 181, 223],
#         ...,
#         [182, 193, 199],
#         [183, 192, 199],
#         [184, 193, 198]],
#
#        [[138, 180, 222],
#         [138, 180, 222],
#         [139, 181, 223],
#         ...,
#         [189, 198, 205],
#         [190, 199, 204],
#         [191, 198, 204]],
#
#        [[138, 180, 222],
#         [139, 181, 223],
#         [139, 181, 223],
#         ...,
#         [198, 205, 211],
#         [198, 206, 209],
#         [201, 206, 210]],
#
#        ...,
#
#        [[210, 214, 217],
#         [216, 220, 223],
#         [201, 205, 208],
#         ...,
#         [180, 187, 195],
#         [184, 191, 199],
#         [192, 199, 207]],
#
#        [[202, 206, 207],
#         [227, 231, 232],
#         [194, 198, 199],
#         ...,
#         [168, 175, 183],
#         [173, 180, 188],
#         [179, 186, 194]],
#
#        [[202, 206, 205],
#         [195, 199, 198],
#         [207, 211, 210],
# ...

# %%
im_flattened = im.reshape(-1)

# %%
im_flattened[0:5]
# Out:
# array([138, 180, 222, 138, 180], dtype=uint8)

# %%
plt.plot(im_flattened[0:500],'.')

# %%
plt.imshow(im);

# %%
plt.figure(figsize=(20,10))
plt.imshow(im);
plt.axis('off');

# %%
im.shape
# Out:
# (127, 398, 3)

# %%
plt.imshow(im[:,:,0],cmap= 'gray')

# %%
plt.imshow(im[:,100:200,:])
